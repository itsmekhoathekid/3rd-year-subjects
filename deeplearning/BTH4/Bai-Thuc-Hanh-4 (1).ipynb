# %% [markdown]
# # BÀI THỰC HÀNH 4: MẠNG NEURON HỒI QUY VÀ CƠ CHẾ TẬP TRUNG - BÀI TOÁN PHÂN LOẠI VĂN BẢN

# %% [markdown]
# <b>Hướng dẫn nộp bài:</b>
# - Folder chứa toàn bộ source code, đặt tên là <b>\<MSSV\>.zip</b> với \<MSSV\> là MSSV của các bạn.
# - Nộp qua course, giảng viên sẽ tạo submission sau mỗi buổi học.
#
# Bộ dữ liệu sử dụng: UIT-ViOCD (link download: https://drive.google.com/drive/folders/1Lu9axyLkw7dMx80uLRgvCnZsmNzhJWAa?usp=sharing)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài 1: Xây dựng mô hình LSTM 3 lớp sử dụng cơ chế tập trung Bahdanau (Bahdanau attention mechanism) và so sánh với mô hình LSTM 3 lớp thông thường.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài 2: Xây dựng mô hình LSTM 3 lớp sử dụng cơ chế tập trung Luong (Luong attention mechanism) và so sánh với mô hình LSTM 3 lớp thông thường.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài 3: Xây dựng mô hình LSTM 3 lớp sử dụng cơ chế tập trung Luong và so sánh với mô hình LSTM 3 lớp sử dụng cơ chế tập trung Bahdanau.
